# %%
import pandas as pd
import numpy as np

# Dados dos coeficientes
data = {
    "Variable": ["(Intercept)", "Setor.CNAECOMERCIO E SERVICOS", "Setor.CNAEINDUSTRIA DE TRANSFORMACAO",
                 "Setor.CNAEINDUSTRIA EXTRATIVA", "Porte.do.clienteMICRO", "Porte.do.clienteMEDIA",
                 "Porte.do.clientePEQUENA", "Proporção.do.Valor.Setorial.ao.PIB.do.UF", "Contribuição.do.UF.ao.PIB.Nacional"],
    "Estimate": [15.35381, -0.24586, 0.33142, -0.11198, -2.46802, -1.76636, -2.41011, 0.01558, 1.20020],
    "Std. Error": [0.09671, 0.12596, 0.09834, 0.38721, 0.18893, 0.04211, 0.13701, 0.05595, 0.13506],
    "t value": [158.753, -1.952, 3.370, -0.289, -13.063, -41.884, -17.524, 0.278, 8.887],
    "Pr(>|t|)": ["<2e-16", "0.050997", "0.000756", "0.772435", "<2e-16", "<2e-16", "<2e-16", "0.780683", "<2e-16"]
}

# Criar DataFrame
df = pd.DataFrame(data)

# Calcular o expoente dos coeficientes
df["Exponentiated Estimate"] = np.exp(df["Estimate"])

# Calcular a mudança percentual
df["Percentual Change"] = (df["Exponentiated Estimate"] - 1) * 100

# Formatando as colunas Exponentiated Estimate e Percentual Change para melhor legibilidade
df["Exponentiated Estimate"] = df["Exponentiated Estimate"].apply(lambda x: f"{x:,.2f}")
df["Percentual Change"] = df["Percentual Change"].apply(lambda x: f"{x:,.2f}%")

# Informações adicionais do resumo do modelo
summary_info = {
    "Residual standard error": 1.3,
    "Degrees of freedom": 7070,
    "Adjusted R-squared": 0.2596,
    "F-statistic": 311.2,
    "p-value": "<2.2e-16"
}

# Função para imprimir as informações de maneira formatada
def print_model_summary(summary):
    print("Model Summary Statistics:")
    print("----------------------------")
    for key, value in summary.items():
        print(f"{key}: {value}")

# Chamando a função para imprimir o resumo do modelo
print_model_summary(summary_info)

# Salvar o DataFrame formatado em Excel
df.to_excel("regressao_semUF.xlsx", index=False)
df
# Out:
# Model Summary Statistics:
# ----------------------------
# Residual standard error: 1.3
# Degrees of freedom: 7070
# Adjusted R-squared: 0.2596
# F-statistic: 311.2
# p-value: <2.2e-16
#                                    Variable  Estimate  Std. Error  t value  \
# 0                               (Intercept)  15.35381     0.09671  158.753
# 1             Setor.CNAECOMERCIO E SERVICOS  -0.24586     0.12596   -1.952
# 2      Setor.CNAEINDUSTRIA DE TRANSFORMACAO   0.33142     0.09834    3.370
# 3             Setor.CNAEINDUSTRIA EXTRATIVA  -0.11198     0.38721   -0.289
# 4                     Porte.do.clienteMICRO  -2.46802     0.18893  -13.063
# 5                     Porte.do.clienteMEDIA  -1.76636     0.04211  -41.884
# 6                   Porte.do.clientePEQUENA  -2.41011     0.13701  -17.524
# 7  Proporção.do.Valor.Setorial.ao.PIB.do.UF   0.01558     0.05595    0.278
# 8        Contribuição.do.UF.ao.PIB.Nacional   1.20020     0.13506    8.887
#
#    Pr(>|t|) Exponentiated Estimate Percentual Change
# 0    <2e-16           4,656,664.61   465,666,360.58%
# 1  0.050997                   0.78           -21.80%
# 2  0.000756                   1.39            39.29%
# 3  0.772435                   0.89           -10.59%
# 4    <2e-16                   0.08           -91.52%
# 5    <2e-16                   0.17           -82.90%
# 6    <2e-16                   0.09           -91.02%
# 7  0.780683                   1.02             1.57%
# 8    <2e-16                   3.32           232.08%

# %%
import pandas as pd

# Dados dos coeficientes para a primeira parte
data_part1 = {
    "Variable": [
        "(Intercept)", "UFAlagoas", "UFAmazonas", "UFBahia", "UFCeará", "UFEspírito Santo", 
        "UFGoiás", "UFMato Grosso", "UFMato Grosso do Sul", "UFMinas Gerais", "UFPará", 
        "UFParaíba", "UFParaná", "UFPernambuco", "UFPiauí", "UFRio de Janeiro", "UFRio Grande do Norte", 
        "UFRio Grande do Sul", "UFRondônia", "UFSanta Catarina", "UFSão Paulo", "UFSergipe", 
        "UFTocantins", "Setor.CNAECOMERCIO E SERVICOS", "Setor.CNAEINDUSTRIA DE TRANSFORMACAO", 
        "Setor.CNAEINDUSTRIA EXTRATIVA", "Porte.do.clienteMEDIA", "Porte.do.clienteMICRO", "Porte.do.clientePEQUENA"
    ],
    "Estimate": [
        12.18308, 3.03169, 4.07721, 3.61986, 3.07468, 3.29770, 2.71205, 2.50728, 2.18979, 
        3.95481, 2.19161, 3.33676, 3.19997, 2.69673, 2.57284, 3.81982, 2.69302, 3.24589, 
        2.16039, 3.19108, 3.73108, 2.11954, 1.17385, -0.43803, 0.14410, -0.25537, -1.71633, 
        -2.53041, -2.39111
    ],
    "Std. Error": [
        1.59296, 1.65248, 1.56321, 1.59362, 1.57483, 1.57421, 1.60882, 1.58122, 1.72379, 
        1.60511, 1.60056, 1.58398, 1.60008, 1.58236, 1.54476, 1.61160, 1.55596, 1.59963, 
        1.54016, 1.59016, 1.61283, 1.58416, 1.62548, 0.13514, 0.10808, 0.38722, 0.04186, 
        0.18761, 0.13587
    ],
    "t value": [
        7.648, 1.835, 2.608, 2.271, 1.952, 2.095, 1.686, 1.586, 1.270, 2.464, 1.369, 2.107, 
        2.000, 1.704, 1.666, 2.370, 1.731, 2.029, 1.403, 2.007, 2.313, 1.338, 0.722, -3.241, 
        1.333, -0.660, -41.000, -13.488, -17.598
    ],
    "Pr(>|t|)": [
        2.31e-14, 0.06660, 0.00912, 0.02315, 0.05093, 0.03622, 0.09189, 0.11286, 0.20401, 
        0.01377, 0.17096, 0.03519, 0.04555, 0.08837, 0.09585, 0.01780, 0.08353, 0.04248, 
        0.16075, 0.04481, 0.02073, 0.18095, 0.47022, 0.00120, 0.18248, 0.50959, 2e-16, 
        2e-16, 2e-16
    ]
}

# Informações de resumo do modelo
model_summary = {
    "Residual standard error": "1.284 on 7049 degrees of freedom",
    "Observations deleted due to missingness": 1,
    "Multiple R-squared": 0.2805,
    "Adjusted R-squared": 0.2775,
    "F-statistic": "94.75 on 29 and 7049 DF",
    "p-value": "< 2.2e-16"
}

# Função para imprimir as informações de maneira formatada
def print_model_summary(summary):
    print("Model Summary Statistics:")
    print("----------------------------")
    for key, value in summary.items():
        print(f"{key}: {value}")

# Chamando a função para imprimir o resumo do modelo
print_model_summary(model_summary)


# Criar DataFrame para a primeira parte
df = pd.DataFrame(data_part1)

# Calcular o expoente dos coeficientes
df["Exponentiated Estimate"] = np.exp(df["Estimate"])

# Calcular a mudança percentual
df["Percentual Change"] = (df["Exponentiated Estimate"] - 1) * 100

# Formatando as colunas Exponentiated Estimate e Percentual Change para melhor legibilidade
df["Exponentiated Estimate"] = df["Exponentiated Estimate"].apply(lambda x: f"{x:,.2f}")
df["Percentual Change"] = df["Percentual Change"].apply(lambda x: f"{x:,.2f}%")


# Combinação dos dataframes (considerando que as variáveis são as mesmas e adicionamos na sequência)
df_final = df  # No caso real, você combinaria com df_part2 se tivesse variáveis diferentes

# Exibir o DataFrame final
df_final
# Out:
# Model Summary Statistics:
# ----------------------------
# Residual standard error: 1.284 on 7049 degrees of freedom
# Observations deleted due to missingness: 1
# Multiple R-squared: 0.2805
# Adjusted R-squared: 0.2775
# F-statistic: 94.75 on 29 and 7049 DF
# p-value: < 2.2e-16
#                                 Variable  Estimate  Std. Error  t value  \
# 0                            (Intercept)  12.18308     1.59296    7.648
# 1                              UFAlagoas   3.03169     1.65248    1.835
# 2                             UFAmazonas   4.07721     1.56321    2.608
# 3                                UFBahia   3.61986     1.59362    2.271
# 4                                UFCeará   3.07468     1.57483    1.952
# 5                       UFEspírito Santo   3.29770     1.57421    2.095
# 6                                UFGoiás   2.71205     1.60882    1.686
# 7                          UFMato Grosso   2.50728     1.58122    1.586
# 8                   UFMato Grosso do Sul   2.18979     1.72379    1.270
# 9                         UFMinas Gerais   3.95481     1.60511    2.464
# 10                                UFPará   2.19161     1.60056    1.369
# 11                             UFParaíba   3.33676     1.58398    2.107
# 12                              UFParaná   3.19997     1.60008    2.000
# 13                          UFPernambuco   2.69673     1.58236    1.704
# 14                               UFPiauí   2.57284     1.54476    1.666
# 15                      UFRio de Janeiro   3.81982     1.61160    2.370
# 16                 UFRio Grande do Norte   2.69302     1.55596    1.731
# 17                   UFRio Grande do Sul   3.24589     1.59963    2.029
# 18                            UFRondônia   2.16039     1.54016    1.403
# 19                      UFSanta Catarina   3.19108     1.59016    2.007
# 20                           UFSão Paulo   3.73108     1.61283    2.313
# 21                             UFSergipe   2.11954     1.58416    1.338
# 22                           UFTocantins   1.17385     1.62548    0.722
# 23         Setor.CNAECOMERCIO E SERVICOS  -0.43803     0.13514   -3.241
# 24  Setor.CNAEINDUSTRIA DE TRANSFORMACAO   0.14410     0.10808    1.333
# 25         Setor.CNAEINDUSTRIA EXTRATIVA  -0.25537     0.38722   -0.660
# 26                 Porte.do.clienteMEDIA  -1.71633     0.04186  -41.000
# 27                 Porte.do.clienteMICRO  -2.53041     0.18761  -13.488
# 28               Porte.do.clientePEQUENA  -2.39111     0.13587  -17.598
#
#         Pr(>|t|) Exponentiated Estimate Percentual Change
# 0   2.310000e-14             195,453.93    19,545,293.42%
# 1   6.660000e-02                  20.73         1,973.22%
# 2   9.120000e-03                  58.98         5,798.07%
# 3   2.315000e-02                  37.33         3,633.23%
# 4   5.093000e-02                  21.64         2,064.30%
# 5   3.622000e-02                  27.05         2,605.04%
# 6   9.189000e-02                  15.06         1,406.01%
# 7   1.128600e-01                  12.27         1,127.15%
# 8   2.040100e-01                   8.93           793.33%
# 9   1.377000e-02                  52.19         5,118.58%
# 10  1.709600e-01                   8.95           794.96%
# 11  3.519000e-02                  28.13         2,712.78%
# 12  4.555000e-02                  24.53         2,353.18%
# 13  8.837000e-02                  14.83         1,383.12%
# 14  9.585000e-02                  13.10         1,210.30%
# 15  1.780000e-02                  45.60         4,459.60%
# 16  8.353000e-02                  14.78         1,377.62%
# 17  4.248000e-02                  25.68         2,468.46%
# 18  1.607500e-01                   8.67           767.45%
# 19  4.481000e-02                  24.31         2,331.47%
# 20  2.073000e-02                  41.72         4,072.41%
# 21  1.809500e-01                   8.33           732.73%
# 22  4.702200e-01                   3.23           223.44%
# 23  1.200000e-03                   0.65           -35.47%
# 24  1.824800e-01                   1.15            15.50%
# 25  5.095900e-01                   0.77           -22.54%
# 26  2.000000e-16                   0.18           -82.03%
# 27  2.000000e-16                   0.08           -92.04%
# 28  2.000000e-16                   0.09           -90.85%

# %%
df_final.to_excel("regressao_comUF.xlsx")
